# %%
import json

file = json.load(open("D:\ollama finetune\json_extraction_dataset_500 (1).json", "r"))
print(file[1])
# Out:
# {'input': "Extract the product information:\n<div class='product'><h2>iPad Air</h2><span class='price'>$1344</span><span class='category'>audio</span><span class='brand'>Dell</span></div>", 'output': {'name': 'iPad Air', 'price': '$1344', 'category': 'audio', 'manufacturer': 'Dell'}}

# %%
# !pip install unsloth trl peft accelerate bitsandbytes
# Out:
# Requirement already satisfied: unsloth in .\venv\lib\site-packages (2026.1.1)
# Requirement already satisfied: trl in .\venv\lib\site-packages (0.22.2)
# Requirement already satisfied: peft in .\venv\lib\site-packages (0.18.0)
# Requirement already satisfied: accelerate in .\venv\lib\site-packages (1.12.0)
# Requirement already satisfied: bitsandbytes in .\venv\lib\site-packages (0.49.0)
# Requirement already satisfied: unsloth_zoo>=2026.1.1 in .\venv\lib\site-packages (from unsloth) (2026.1.1)
# Requirement already satisfied: wheel>=0.42.0 in .\venv\lib\site-packages (from unsloth) (0.45.1)
# Requirement already satisfied: packaging in .\venv\lib\site-packages (from unsloth) (25.0)
# Requirement already satisfied: torch>=2.4.0 in .\venv\lib\site-packages (from unsloth) (2.9.1)
# Requirement already satisfied: torchvision in .\venv\lib\site-packages (from unsloth) (0.24.1)
# Requirement already satisfied: numpy in .\venv\lib\site-packages (from unsloth) (2.2.6)
# Requirement already satisfied: tqdm in .\venv\lib\site-packages (from unsloth) (4.67.1)
# Requirement already satisfied: psutil in .\venv\lib\site-packages (from unsloth) (7.2.1)
# Requirement already satisfied: tyro in .\venv\lib\site-packages (from unsloth) (1.0.3)
# Requirement already satisfied: protobuf in .\venv\lib\site-packages (from unsloth) (6.33.2)
# Requirement already satisfied: xformers>=0.0.27.post2 in .\venv\lib\site-packages (from unsloth) (0.0.33.post2)
# Requirement already satisfied: triton-windows in .\venv\lib\site-packages (from unsloth) (3.5.1.post24)
# Requirement already satisfied: sentencepiece>=0.2.0 in .\venv\lib\site-packages (from unsloth) (0.2.1)
# Requirement already satisfied: datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1 in .\venv\lib\site-packages (from unsloth) (4.3.0)
# Requirement already satisfied: huggingface_hub>=0.34.0 in .\venv\lib\site-packages (from unsloth) (0.36.0)
# Requirement already satisfied: hf_transfer in .\venv\lib\site-packages (from unsloth) (0.1.9)
# Requirement already satisfied: diffusers in .\venv\lib\site-packages (from unsloth) (0.36.0)
# Requirement already satisfied: transformers!=4.52.0,!=4.52.1,!=4.52.2,!=4.52.3,!=4.53.0,!=4.54.0,!=4.55.0,!=4.55.1,!=4.57.0,<=4.57.3,>=4.51.3 in .\venv\lib\site-packages (from unsloth) (4.56.2)
# Requirement already satisfied: filelock in .\venv\lib\site-packages (from datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (3.20.2)
# Requirement already satisfied: pyarrow>=21.0.0 in .\venv\lib\site-packages (from datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (22.0.0)
# Requirement already satisfied: dill<0.4.1,>=0.3.0 in .\venv\lib\site-packages (from datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (0.4.0)
# Requirement already satisfied: pandas in .\venv\lib\site-packages (from datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (2.3.3)
# Requirement already satisfied: requests>=2.32.2 in .\venv\lib\site-packages (from datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (2.32.5)
# Requirement already satisfied: httpx<1.0.0 in .\venv\lib\site-packages (from datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (0.28.1)
# Requirement already satisfied: xxhash in .\venv\lib\site-packages (from datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in .\venv\lib\site-packages (from datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (0.70.16)
# Requirement already satisfied: fsspec<=2025.9.0,>=2023.1.0 in .\venv\lib\site-packages (from fsspec[http]<=2025.9.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (2025.9.0)
# Requirement already satisfied: pyyaml>=5.1 in .\venv\lib\site-packages (from datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (6.0.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in .\venv\lib\site-packages (from fsspec[http]<=2025.9.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (3.13.3)
# Requirement already satisfied: anyio in .\venv\lib\site-packages (from httpx<1.0.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (4.12.0)
# Requirement already satisfied: certifi in .\venv\lib\site-packages (from httpx<1.0.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in .\venv\lib\site-packages (from httpx<1.0.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (1.0.9)
# Requirement already satisfied: idna in .\venv\lib\site-packages (from httpx<1.0.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (3.11)
# Requirement already satisfied: h11>=0.16 in .\venv\lib\site-packages (from httpcore==1.*->httpx<1.0.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (0.16.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in .\venv\lib\site-packages (from huggingface_hub>=0.34.0->unsloth) (4.15.0)
# Requirement already satisfied: regex!=2019.12.17 in .\venv\lib\site-packages (from transformers!=4.52.0,!=4.52.1,!=4.52.2,!=4.52.3,!=4.53.0,!=4.54.0,!=4.55.0,!=4.55.1,!=4.57.0,<=4.57.3,>=4.51.3->unsloth) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in .\venv\lib\site-packages (from transformers!=4.52.0,!=4.52.1,!=4.52.2,!=4.52.3,!=4.53.0,!=4.54.0,!=4.55.0,!=4.55.1,!=4.57.0,<=4.57.3,>=4.51.3->unsloth) (0.22.1)
# Requirement already satisfied: safetensors>=0.4.3 in .\venv\lib\site-packages (from transformers!=4.52.0,!=4.52.1,!=4.52.2,!=4.52.3,!=4.53.0,!=4.54.0,!=4.55.0,!=4.55.1,!=4.57.0,<=4.57.3,>=4.51.3->unsloth) (0.7.0)
# Requirement already satisfied: sympy>=1.13.3 in .\venv\lib\site-packages (from torch>=2.4.0->unsloth) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in .\venv\lib\site-packages (from torch>=2.4.0->unsloth) (3.4.2)
# Requirement already satisfied: jinja2 in .\venv\lib\site-packages (from torch>=2.4.0->unsloth) (3.1.6)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in .\venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in .\venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (1.4.0)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in .\venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (5.0.1)
# Requirement already satisfied: attrs>=17.3.0 in .\venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in .\venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in .\venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in .\venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in .\venv\lib\site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.9.0,>=2023.1.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (1.22.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in .\venv\lib\site-packages (from requests>=2.32.2->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in .\venv\lib\site-packages (from requests>=2.32.2->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (2.6.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in .\venv\lib\site-packages (from sympy>=1.13.3->torch>=2.4.0->unsloth) (1.3.0)
# Requirement already satisfied: colorama in .\venv\lib\site-packages (from tqdm->unsloth) (0.4.6)
# Requirement already satisfied: torchao>=0.13.0 in .\venv\lib\site-packages (from unsloth_zoo>=2026.1.1->unsloth) (0.15.0)
# Requirement already satisfied: cut_cross_entropy in .\venv\lib\site-packages (from unsloth_zoo>=2026.1.1->unsloth) (25.1.1)
# Requirement already satisfied: pillow in .\venv\lib\site-packages (from unsloth_zoo>=2026.1.1->unsloth) (12.1.0)
# Requirement already satisfied: msgspec in .\venv\lib\site-packages (from unsloth_zoo>=2026.1.1->unsloth) (0.20.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in .\venv\lib\site-packages (from anyio->httpx<1.0.0->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (1.3.1)
# Requirement already satisfied: importlib_metadata in .\venv\lib\site-packages (from diffusers->unsloth) (8.7.1)
# Requirement already satisfied: zipp>=3.20 in .\venv\lib\site-packages (from importlib_metadata->diffusers->unsloth) (3.23.0)
# Requirement already satisfied: MarkupSafe>=2.0 in .\venv\lib\site-packages (from jinja2->torch>=2.4.0->unsloth) (3.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in .\venv\lib\site-packages (from pandas->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in .\venv\lib\site-packages (from pandas->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in .\venv\lib\site-packages (from pandas->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (2025.3)
# Requirement already satisfied: six>=1.5 in .\venv\lib\site-packages (from python-dateutil>=2.8.2->pandas->datasets!=4.0.*,!=4.1.0,<4.4.0,>=3.4.1->unsloth) (1.17.0)
# Requirement already satisfied: docstring-parser>=0.15 in .\venv\lib\site-packages (from tyro->unsloth) (0.17.0)
# Requirement already satisfied: typeguard>=4.0.0 in .\venv\lib\site-packages (from tyro->unsloth) (4.4.4)

# %%
# For GPU check
import torch
print(f"CUDA available: {torch.cuda.is_available()}")
print(f"GPU: {torch.cuda.get_device_name(0) if torch.cuda.is_available() else 'None'}")
# Out:
# CUDA available: False
# GPU: None

# %%
from unsloth import FastLanguageModel
import torch

model_name = "unsloth/Phi-3-mini-4k-instruct-bnb-4bit"

max_seq_length = 2048  # Choose sequence length
dtype = None  # Auto detection

# Load model and tokenizer
model, tokenizer = FastLanguageModel.from_pretrained(
    model_name=model_name,
    max_seq_length=max_seq_length,
    dtype=dtype,
    load_in_4bit=True,
)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 from unsloth import FastLanguageModel
#       2 import torch
#       4 model_name = "unsloth/Phi-3-mini-4k-instruct-bnb-4bit"
#
# File d:\ollama finetune\venv\lib\site-packages\unsloth\__init__.py:95
#      83         print(
#      84             "Unsloth: Please update Unsloth and Unsloth-Zoo to the latest version!\n"
#      85             "Do this via `pip install --upgrade --force-reinstall --no-cache-dir --no-deps unsloth unsloth_zoo`"
#      86         )
#      87         # if os.environ.get("UNSLOTH_DISABLE_AUTO_UPDATES", "0") == "0":
#      88         #     try:
#      89         #         os.system("pip install --upgrade --no-cache-dir --no-deps unsloth_zoo")
#    (...)
#      93         #         except:
#      94         #             raise ImportError("Unsloth: Please update unsloth_zoo via `pip install --upgrade --no-cache-dir --no-deps unsloth_zoo`")
# ---> 95     import unsloth_zoo
#      96 except PackageNotFoundError:
#      97     raise ImportError(
#      98         f"Unsloth: Please install unsloth_zoo via `pip install unsloth_zoo` then retry!"
#      99     )
#
# File d:\ollama finetune\venv\lib\site-packages\unsloth_zoo\__init__.py:146
#     143 del logging, torchao_logger, HideLoggingMessage
#     145 # Get device types and other variables
# --> 146 from .device_type import (
#     147     is_hip,
#     148     get_device_type,
#     149     DEVICE_TYPE,
#     150     DEVICE_TYPE_TORCH,
#     151     DEVICE_COUNT,
#     152     ALLOW_PREQUANTIZED_MODELS,
#     153 )
#     155 # Torch 2.9 removed PYTORCH_HIP_ALLOC_CONF and PYTORCH_CUDA_ALLOC_CONF
#     156 if major_torch == 2 and minor_torch >= 9:
#
# File d:\ollama finetune\venv\lib\site-packages\unsloth_zoo\device_type.py:56
#      54     raise NotImplementedError("Unsloth currently only works on NVIDIA, AMD and Intel GPUs.")
#      55 pass
# ---> 56 DEVICE_TYPE : str = get_device_type()
#      57 # HIP fails for autocast and other torch functions. Use CUDA instead
#      58 DEVICE_TYPE_TORCH = DEVICE_TYPE
#
# File d:\ollama finetune\venv\lib\site-packages\unsloth_zoo\device_type.py:46, in get_device_type()
#      44 if hasattr(torch, "accelerator"):
#      45     if not torch.accelerator.is_available():
# ---> 46         raise NotImplementedError("Unsloth cannot find any torch accelerator? You need a GPU.")
#      47     accelerator = str(torch.accelerator.current_accelerator())
#      48     if accelerator in ("cuda", "xpu", "hip"):
#
# NotImplementedError: Unsloth cannot find any torch accelerator? You need a GPU.

# %%
from datasets import Dataset

def format_prompt(example):
    return f"### Input: {example['input']}\n### Output: {json.dumps(example['output'])}<|endoftext|>"

formatted_data = [format_prompt(item) for item in file]
dataset = Dataset.from_dict({"text": formatted_data})

# %%
# Add LoRA adapters
model = FastLanguageModel.get_peft_model(
    model,
    r=64,  # LoRA rank - higher = more capacity, more memory
    target_modules=[
        "q_proj", "k_proj", "v_proj", "o_proj",
        "gate_proj", "up_proj", "down_proj",
    ],
    lora_alpha=128,  # LoRA scaling factor (usually 2x rank)
    lora_dropout=0,  # Supports any, but = 0 is optimized
    bias="none",     # Supports any, but = "none" is optimized
    use_gradient_checkpointing="unsloth",  # Unsloth's optimized version
    random_state=3407,
    use_rslora=False,  # Rank stabilized LoRA
    loftq_config=None, # LoftQ
)

# %%
from trl import SFTTrainer
from transformers import TrainingArguments

# Training arguments optimized for Unsloth
trainer = SFTTrainer(
    model=model,
    tokenizer=tokenizer,
    train_dataset=dataset,
    dataset_text_field="text",
    max_seq_length=max_seq_length,
    dataset_num_proc=2,
    args=TrainingArguments(
        per_device_train_batch_size=2,
        gradient_accumulation_steps=4,  # Effective batch size = 8
        warmup_steps=10,
        num_train_epochs=3,
        learning_rate=2e-4,
        fp16=not torch.cuda.is_bf16_supported(),
        bf16=torch.cuda.is_bf16_supported(),
        logging_steps=25,
        optim="adamw_8bit",
        weight_decay=0.01,
        lr_scheduler_type="linear",
        seed=3407,
        output_dir="outputs",
        save_strategy="epoch",
        save_total_limit=2,
        dataloader_pin_memory=False,
    ),
)

# %%
# Train the model
trainer_stats = trainer.train()

# %%
# Test the fine-tuned model
FastLanguageModel.for_inference(model) # Enable native 2x faster inference

# Test prompt
messages = [
    {"role": "user", "content": "Extract the product information:\n<div class='product'><h2>iPad Air</h2><span class='price'>$1344</span><span class='category'>audio</span><span class='brand'>Dell</span></div>"},
]

inputs = tokenizer.apply_chat_template(
    messages,
    tokenize=True,
    add_generation_prompt=True,
    return_tensors="pt",
).to("cuda")

# Generate response
outputs = model.generate(
    input_ids=inputs,
    max_new_tokens=256,
    use_cache=True,
    temperature=0.7,
    do_sample=True,
    top_p=0.9,
)

# Decode and print
response = tokenizer.batch_decode(outputs)[0]
print(response)

# %%
model.save_pretrained_gguf("gguf_model", tokenizer, quantization_method="q4_k_m")

# %%
gguf_files = [f for f in os.listdir("gguf_model") if f.endswith(".gguf")]
if gguf_files:
    gguf_file = os.path.join("gguf_model", gguf_files[0])
    print(f"Downloading: {gguf_file}")
    files.download(gguf_file)
